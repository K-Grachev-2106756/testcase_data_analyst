# %% [markdown]
# # Первое задание

# %%
# !pip3 install pandas
import pandas as pd
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.23.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %%
df = pd.read_csv('./task.csv')
df
# Out:
#             area  cluster cluster_name                     keyword  good (1)  \
# 0    eligibility      0.0    Кластер 0     several animated buried       1.0
# 1    eligibility      0.0    Кластер 0      singles unusual buyers       1.0
# 2    eligibility      0.0    Кластер 0          hawaiian directive       1.0
# 3    eligibility      0.0    Кластер 0           dynamics directly       1.0
# 4    eligibility      1.0    Кластер 1  decision surgeons montreal       1.0
# ..           ...      ...          ...                         ...       ...
# 224    greetings      2.0    Кластер 2          disposition layout       1.0
# 225    greetings      2.0    Кластер 2            sapphire grounds       1.0
# 226    greetings      3.0    Кластер 3     entire ethical speakers       1.0
# 227    greetings      3.0    Кластер 3  courtesy textiles diameter       1.0
# 228    greetings      3.0    Кластер 3              comfort rivers       1.0
#
#     count          x                   y
# 0    1260   5.772342  12.564796257345005
# 1     866  14.829280  7.8507285727125815
# 2     163  11.381856  3.8981370219558604
# 3    1146   9.980149   6.281427914064545
# 4     823   3.283940    4.39674063521296
# ..    ...        ...                 ...
# 224   279  10.971214   4.857810387061303
# 225   335   1.160626   3.642819729434763
# 226  1782   7.985910   6.003699268483375
# 227    84   0.509490   4.151198803764073
# 228  1806   6.961866   6.435589561443678
#
# [229 rows x 8 columns]

# %%
df.info() # Посмотрим на состояние данных
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 229 entries, 0 to 228
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   area          228 non-null    object
#  1   cluster       228 non-null    float64
#  2   cluster_name  228 non-null    object
#  3   keyword       228 non-null    object
#  4   good (1)      227 non-null    float64
#  5   count         227 non-null    object
#  6   x             228 non-null    float64
#  7   y             228 non-null    object
# dtypes: float64(3), object(5)
# memory usage: 14.4+ KB

# %%
pd.unique(df.cluster) # Есть пропущенные значения
# Out:
# array([ 0.,  1.,  2.,  3., nan])

# %%
def custom_to_float(value): # Для преобразования всех возможных вариантов обозначения NaN к одному - float('nan')
    try:
        return float(value)
    except (ValueError, TypeError):
        return float('nan')

df['y'] = df['y'].apply(custom_to_float) # Сейчас столбец имеет тип object, но там хранятся float координаты
df['count'] = df['count'].apply(custom_to_float) # Сейчас столбец имеет тип object, но там хранятся int значения
df.dropna(inplace = True)
df['cluster'] = df['cluster'].astype(int)
df['count'] = df['count'].astype(int)
df.info() # Привели всё к нужным типам данных
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 223 entries, 0 to 228
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   area          223 non-null    object
#  1   cluster       223 non-null    int64
#  2   cluster_name  223 non-null    object
#  3   keyword       223 non-null    object
#  4   good (1)      223 non-null    float64
#  5   count         223 non-null    int64
#  6   x             223 non-null    float64
#  7   y             223 non-null    float64
# dtypes: float64(3), int64(2), object(3)
# memory usage: 15.7+ KB

# %%
pd.unique(df.cluster)
# Out:
# array([0, 1, 2, 3])

# %%
colors = {k: v for k, v in zip(pd.unique(df.cluster), ['#17becf', '#bcbd22', '#7f7f7f','#e377c2'])}
colors # Чтобы задать цвет каждому кластеру (по условию, кластеры разных областей могут быть одного цвета)
# Out:
# {0: '#17becf', 1: '#bcbd22', 2: '#7f7f7f', 3: '#e377c2'}

# %%
df['color'] = df['cluster'].map(colors)
df.drop('good (1)', axis = 1, inplace = True)
df # Удалили ненужные по условию столбцы
# Out:
#             area  cluster cluster_name                     keyword  count  \
# 0    eligibility        0    Кластер 0     several animated buried   1260
# 1    eligibility        0    Кластер 0      singles unusual buyers    866
# 2    eligibility        0    Кластер 0          hawaiian directive    163
# 3    eligibility        0    Кластер 0           dynamics directly   1146
# 4    eligibility        1    Кластер 1  decision surgeons montreal    823
# ..           ...      ...          ...                         ...    ...
# 224    greetings        2    Кластер 2          disposition layout    279
# 225    greetings        2    Кластер 2            sapphire grounds    335
# 226    greetings        3    Кластер 3     entire ethical speakers   1782
# 227    greetings        3    Кластер 3  courtesy textiles diameter     84
# 228    greetings        3    Кластер 3              comfort rivers   1806
#
#              x          y    color
# 0     5.772342  12.564796  #17becf
# 1    14.829280   7.850729  #17becf
# 2    11.381856   3.898137  #17becf
# 3     9.980149   6.281428  #17becf
# 4     3.283940   4.396741  #bcbd22
# ..         ...        ...      ...
# 224  10.971214   4.857810  #7f7f7f
# 225   1.160626   3.642820  #7f7f7f
# 226   7.985910   6.003699  #e377c2
# 227   0.509490   4.151199  #e377c2
# 228   6.961866   6.435590  #e377c2
#
# [223 rows x 8 columns]

# %%
df.drop_duplicates(subset = ['area', 'keyword'], keep = False, inplace = True)
len(df) # Избавились от дублирующихся ключевых слов внутри одной области
# Out:
# 209

# %%
df = df.sort_values(by = ['area', 'cluster', 'cluster_name', 'count'], ascending = [True, True, True, False])
df # Произвели сортировку данных
# Out:
#        area  cluster cluster_name                             keyword  count  \
# 106   ar\vr        0    Кластер 0           written conflict fabulous   1443
# 108   ar\vr        0    Кластер 0                reservations linking    751
# 107   ar\vr        0    Кластер 0                  interfaces neutral    586
# 109   ar\vr        0    Кластер 0                 committees parallel    173
# 110   ar\vr        1    Кластер 1  postcards looked republic detector   1397
# ..      ...      ...          ...                                 ...    ...
# 100  worlds        2    Кластер 2                   ringtone parental    471
# 102  worlds        2    Кластер 2                   recipient traffic    236
# 105  worlds        3    Кластер 3                   immunology plates   1653
# 103  worlds        3    Кластер 3                     holdings herbal   1476
# 104  worlds        3    Кластер 3                    exchanges castle   1097
#
#              x          y    color
# 106   2.991167   7.106799  #17becf
# 108  10.195602  12.259496  #17becf
# 107  10.443533  13.809915  #17becf
# 109   6.735260   3.613983  #17becf
# 110  10.474474   6.220012  #bcbd22
# ..         ...        ...      ...
# 100  11.723895   4.363994  #7f7f7f
# 102   5.593629   0.553368  #7f7f7f
# 105   2.407028   7.651527  #e377c2
# 103   3.986508  10.906340  #e377c2
# 104   8.082231   6.587933  #e377c2
#
# [209 rows x 8 columns]

# %%
def check() -> bool:
    def custom_to_float(value):
        try:
            return float(value)
        except (ValueError, TypeError):
            return float('nan')

    df_check = pd.read_csv('./task.csv')
    df_check['y'] = df_check['y'].apply(custom_to_float)
    df_check['count'] = df_check['count'].apply(custom_to_float)
    df_check.dropna(inplace = True)
    if len(df_check) - len(df) == len(pd.concat(g for _, g in df_check.groupby(['area', 'keyword']) if len(g) > 1)):
        print("It's all right")
    else:
        print("Something goes wrong")

check() # Проверили свою работу
# Out:
# It's all right

# %%
df.to_csv('to_spreadsheet.csv', index = False, sep = ',', encoding = 'utf-16') # Сохранили файл в кодировке utf-16, необходимой для корректного отображения колонки cluster_name
